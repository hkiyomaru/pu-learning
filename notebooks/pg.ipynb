# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Get positive negative data

# %%
from scar import load_scar
train, valid, test = load_scar()

# %%
x, y, s = train

# %% [markdown]
# ### Labeling

# %%
from labeling import LabelingMechanism, label_frequency

def get_sample(data, lm, is_train=False):
    x, y, _ = data
    if is_train:
        lm.fit(x)
    score = lm.propensity_score(x)
    s = (y * (np.random.uniform(size=x.shape[0]) < score)).astype(int)
    return x, y, s

# %%
lm = LabelingMechanism([0,1],[1,1], min_prob=0, max_prob=1)

# %%
train = get_sample(train, lm, is_train=True)
valid = get_sample(valid, lm)
test = get_sample(test, lm)

# %%
x, y, s = train

# %%
c = label_frequency(x, y, lm)
print(c)
# Out:
# 0.17378894009288337

# %% [markdown]
# ### Save param

# %%
import json
param = {"minx" : list(lm.minx),
         "maxx" : list(lm.maxx),
         "c" : c}
json_file = open("pg/param.json", "w")
json.dump(param, json_file)
print(param)
# Out:
# {'minx': [-3.607771873474121, -3.41719388961792], 'maxx': [6.421125411987305, 6.955304145812988], 'c': 0.17378894009288337}

# %% [markdown]
# ### Visualize created data

# %%
from utils import plot_x_y
plot_x_y(x, y)
# Out:
# <div>                            <div id="5bb2f9d9-ef09-4b35-ba1f-1a2c90260495" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bb2f9d9-ef09-4b35-ba1f-1a2c90260495")) {                    Plotly.newPlot(                        "5bb2f9d9-ef09-4b35-ba1f-1a2c90260495",                        [{"hovertemplate":"y=Negative<br>x_0=%{x}<br>x_1=%{y}<extra></extra>","legendgroup":"Negative","marker":{"color":"#FF6347","symbol":"circle"},"mode":"markers","name":"Negative","showlegend":true,"type":"scattergl","x":[-0.4327288568019867,-0.7928156852722168,0.5716183185577393,-0.4780022203922272,-0.7396926283836365,1.1387401819229126,2.7843868732452393,-0.6816015243530273,-1.1944211721420288,-0.30192169547080994,0.11891643702983856,-0.8304381966590881,0.0850084125995636,0.6250379085540771,0.2343061864376068,1.837127923965454,-0.027805155143141747,-0.6478182673454285,-1.586574912071228,-2.3644869327545166,-0.5686497092247009,-0.16888992488384247,-0.42679792642593384,-1.469685673713684,-0.06963389366865158,-1.4839959144592285,-0.7625680565834045,0.05776698514819145,0.29013344645500183,-1.0266449451446533,-0.8324242830276489,1.4845397472381592,-0.09378845989704132,1.4613862037658691,1.9164525270462036,-0.197980135679245,-0.6973161697387695,-1.97200345993042,-0.4798542857170105,-0.8390634655952454,1.9933956861495972,0.282515287399292,0.3796401619911194,1.079831600189209,-0.5283939242362976,0.3969833254814148,0.17212828993797302,0.6266363859176636,-1.873409628868103,0.07415061444044113,0.6454867720603943,1.8732465505599976,0.38265305757522583,-1.3942101001739502,-1.1929415464401245,0.5231010317802429,2.108416795730591,-0.43013834953308105,-0.5387566089630127,0.650757372379303,-0.6139091849327087,-0.20204117894172668,-0.8374550938606262,-0.5306645035743713,-0.722200870513916,-0.882696807384491,-0.38310861587524414,0.6314470171928406,-1.8288004398345947,0.22887523472309113,1.4511628150939941,-0.6765044331550598,1.1225751638412476,-1.5865962505340576
652126312256,2.7722387313842773,-0.027805155143141747,-0.6478182673454285,-1.586574912071228,3.992494821548462,3.5534675121307373,-2.3644869327545166,2.2723748683929443,3.5719428062438965,1.894382357597351,3.483428478240967,1.265019416809082,-0.5686497092247009,4.419294834136963,3.8434200286865234,4.979114055633545,3.943873167037964,2.3972578048706055,3.5974960327148438,-0.16888992488384247,4.8707804679870605,-0.42679792642593384,2.748248338699341,-1.469685673713684,0.4209177494049072,5.1714372634887695,2.1545376777648926,2.568761110305786,1.1586005687713623,0.5271214246749878,-0.06963389366865158,2.0022082328796387,-1.4839959144592285,4.3568806648254395,-0.7625680565834045,3.269059896469116,3.4400689601898193,2.832315444946289,4.728851795196533,3.952491283416748,3.24499773979187,3.6407322883605957,0.05776698514819145,3.800591230392456,2.8032543659210205,4.184699535369873,2.7383921146392822,0.29013344645500183,4.517271995544434,3.192535877227783,3.3761134147644043,1.5059033632278442,2.490840435028076,-1.0266449451446533,3.024759531021118,1.8618475198745728,-0.8324242830276489,1.4845397472381592,4.334804058074951,0.9751692414283752,2.835818290710449,1.56089186668396,2.702543258666992,1.9025113582611084,-0.09378845989704132,2.0869665145874023,1.2150402069091797,1.4613862037658691,3.029019832611084,1.0324450731277466,3.1866416931152344,3.00652813911438,2.377537488937378,2.873239755630493,1.9164525270462036,4.311882972717285,2.8665482997894287,2.3745579719543457,-0.197980135679245,-0.6973161697387695,1.0572445392608643,3.275707721710205,3.591261386871338,3.5804619789123535,3.2705323696136475,3.8071112632751465,3.1723837852478027,2.026765823364258,-1.97200345993042,2.9975388050079346,3.635573148727417,3.3810861110687256,2.5414505004882812,-0.4798542857170105,3.794752836227417,-0.8390634655952454,1.9933956861495972,0.282515287399292,1.6711434125900269,0.3796401619911194,3.2150282859802246,3.519880771636963,3.3793582916259766,2.811309814453125,1.079831600189209,3.329779863357544,2.0075976848602295,2.6989574432373047,3.7104105949401855,2.8648083209991455,4.469063758850098,-0.5283939242362976,2.0904836654663086,2.612226963043213,2.245675563812256,0.3969833254814148,0.17212828993797302,3.7576427459716797,4.5164361000061035,2.738720417022705,2.4071595668792725,2.813091993331909,1.013048768043518,0.6266363859176636,-1.873409628868103,0.07415061444044113,2.36752986907959,0.6454867720603943,1.8270827531814575,1.8732465505599976,1.4136393070220947,0.382653057575 ...

# %% [markdown]
# ### Save data

# %%
with open("pg/train.csv", "wt") as f:
    x, y, s = train
    f.write("x_0,x_1,y,s\n")
    for i in range(len(x)):
        f.write(f"{x[i][0]},{x[i][1]},{y[i]},{s[i]}\n")

with open("pg/valid.csv", "wt") as f:
    x, y, s = valid
    f.write("x_0,x_1,y,s\n")
    for i in range(len(x)):
        f.write(f"{x[i][0]},{x[i][1]},{y[i]},{s[i]}\n")

with open("pg/test.csv", "wt") as f:
    x, y, s = test
    f.write("x_0,x_1,y,s\n")
    for i in range(len(x)):
        f.write(f"{x[i][0]},{x[i][1]},{y[i]},{s[i]}\n")
